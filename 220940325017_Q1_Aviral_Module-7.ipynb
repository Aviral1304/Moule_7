# %% [markdown]
# # Question 1

# %%
# Import library 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading Data
df= pd.read_csv(r'D:\Cdac\Module exam\Module 7 exam\Exam_dataset\data_1.csv.xls')

# %%
# Data Exploration and understanding

# %%
#checking top 10 values
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
# checking the basic information about data types of column and total rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#Checking no. of rows and columns
df.shape
# Out:
# (301, 9)

# %%
#checking the size of dataframe
df.size
# Out:
# 2709

# %%
# checking dimension
df.ndim
# Out:
# 2

# %%
# Getting description about the dataframe like min,max,std ,etc
df.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       301   301.000000     301.000000     301.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.628472   36947.205980
# std         NaN     2.891554       5.082812       8.644115   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       6.400000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# ...

# %%
# Checking bottom values
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
# Data Cleaning

# %%
#checking duplicates value
df.duplicated().sum()
# Out:
# 2

# %%
# droping duplicate value
df.drop_duplicates()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# checking null values
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# No null is present in the dataset

# %%
#Data Preprocessing and visualization

# %%
# Checking unique data of categorical data type of each column

# %%
df['Car_Name'].value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
df=df.drop(['Car_Name'],axis=1) # we can drop this column as they are many unique car names and it is not required for our model building also

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df['Seller_Type'].value_counts()
# Out:
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64

# %%
df['Transmission'].value_counts()
# Out:
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
df['Owner'].value_counts()
# Out:
# 0    290
# 1     10
# 3      1
# Name: Owner, dtype: int64

# %%
#Plotting Graph for selling Price and present price
plt.scatter(x=df['Selling_Price'],y=df['Present_Price'])

# %%
# Plotting selling price over time
df.groupby(df.Year)['Selling_Price'].mean().plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='Year'>

# %%
sns.countplot(df['Year'],hue=df['Fuel_Type'],data=df)
# Out:
# C:\Users\avira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='Year', ylabel='count'>

# %%
df.corr() # finding correlation
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
# Transmission Vs Selling Price
plt.bar(df.Transmission,df.Selling_Price)
# Out:
# <BarContainer object of 301 artists>

# %%
sns.boxplot(df['Selling_Price'])
# Out:
# C:\Users\avira\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='Selling_Price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    object
#  5   Seller_Type    301 non-null    object
#  6   Transmission   301 non-null    object
#  7   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 18.9+ KB

# %%
# Creating number of years from given year column as price depends on the year 
df['Present_Year']=2023
df['Year']=df['Present_Year']-df['Year']
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       9           3.35           5.59       27000    Petrol      Dealer
# 1      10           4.75           9.54       43000    Diesel      Dealer
# 2       6           7.25           9.85        6900    Petrol      Dealer
# 3      12           2.85           4.15        5200    Petrol      Dealer
# 4       9           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296     7           9.50          11.60       33988    Diesel      Dealer
# 297     8           4.00           5.90       60000    Petrol      Dealer
# 298    14           3.35          11.00       87934    Petrol      Dealer
# 299     6          11.50          12.50        9000    Diesel      Dealer
# 300     7           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Present_Year
# 0         Manual      0          2023
# ...

# %%
#Droping present year as it is of no use now
df=df.drop(['Present_Year'],axis=1)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       9           3.35           5.59       27000    Petrol      Dealer
# 1      10           4.75           9.54       43000    Diesel      Dealer
# 2       6           7.25           9.85        6900    Petrol      Dealer
# 3      12           2.85           4.15        5200    Petrol      Dealer
# 4       9           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296     7           9.50          11.60       33988    Diesel      Dealer
# 297     8           4.00           5.90       60000    Petrol      Dealer
# 298    14           3.35          11.00       87934    Petrol      Dealer
# 299     6          11.50          12.50        9000    Diesel      Dealer
# 300     7           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
#creating Dummies
df=pd.get_dummies(df)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  \
# 0       9           3.35           5.59       27000      0              0
# 1      10           4.75           9.54       43000      0              0
# 2       6           7.25           9.85        6900      0              0
# 3      12           2.85           4.15        5200      0              0
# 4       9           4.60           6.87       42450      0              0
# ..    ...            ...            ...         ...    ...            ...
# 296     7           9.50          11.60       33988      0              0
# 297     8           4.00           5.90       60000      0              0
# 298    14           3.35          11.00       87934      0              0
# 299     6          11.50          12.50        9000      0              0
# 300     7           5.30           5.90        5464      0              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# ...

# %%
x=df.drop(['Selling_Price'],axis=1) # separting independent variable
x
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0       9           5.59       27000      0              0                 0
# 1      10           9.54       43000      0              0                 1
# 2       6           9.85        6900      0              0                 0
# 3      12           4.15        5200      0              0                 0
# 4       9           6.87       42450      0              0                 1
# ..    ...            ...         ...    ...            ...               ...
# 296     7          11.60       33988      0              0                 1
# 297     8           5.90       60000      0              0                 0
# 298    14          11.00       87934      0              0                 0
# 299     6          12.50        9000      0              0                 1
# 300     7           5.90        5464      0              0                 0
#
# ...

# %%
y=df['Selling_Price'] # separting dependent variable
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
# Normalisation as there is so much variance in independent variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.128897  , -0.23621461, -0.25622446, ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [ 0.21751369,  0.22150462,  0.1559105 , ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [-1.16812909,  0.25742689, -0.77396901, ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        ...,
#        [ 1.60315648,  0.39068691,  1.31334003, ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [-1.16812909,  0.56450434, -0.7198763 , ..., -0.73728539,
#         -0.39148015,  0.39148015],
#        [-0.8217184 , -0.20029235, -0.81095812, ..., -0.73728539,
#         -0.39148015,  0.39148015]])

# %%
# Splitting data into traing and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# Model Building for Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Predicted value for linear model
y_pred_l=model1.predict(x_test)
y_pred_l
# Out:
# array([ 7.51749959, -0.38136   ,  4.2559471 ,  9.00719207, 14.4269339 ,
#         4.87144495,  3.50800415,  1.44729345,  5.3451756 ,  4.61435641,
#         2.26758534,  1.6209573 ,  5.0502457 ,  7.5592941 ,  8.60637169,
#        13.98391877,  7.32792948,  4.23074458, -0.43329109,  2.36959252,
#         4.98862734,  3.82566592,  6.43249291,  8.02059313, -1.89494718,
#         1.92952344, -0.82194725,  0.82000278,  0.0287008 ,  7.09763522,
#         3.56594643,  7.42982762,  0.72122573,  7.93570184,  3.51526022,
#         1.8051379 ,  5.54534144,  6.9878273 , -2.62961763,  9.08622868,
#         9.21468651, 20.02249841,  4.37997532,  3.85349481,  6.66353853,
#         9.8481939 ,  0.13251979,  1.68098927,  5.0992548 ,  7.35232556,
#         8.07177253,  4.17227139,  4.84915569, 20.36876087,  1.7479962 ,
#         1.30291959,  0.30682078,  1.98321103,  3.37503799,  0.87901548,
#         3.52730876])

# %%
# calculating Mean Squared error
from sklearn import metrics
metrics.mean_squared_error(y_test,y_pred_l)
# Out:
# 2.1628715277876056

# %%
#Summary for linear model
import statsmodels.api as sm
x_stats=sm.add_constant(x_train)
summ=sm.OLS(y_train,x_stats).fit()
summ.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     199.2
# Date:                Mon, 23 Jan 2023   Prob (F-statistic):           3.81e-99
# Time:                        17:44:15   Log-Likelihood:                -482.43
# No. Observations:                 240   AIC:                             982.9
# Df Residuals:                     231   BIC:                             1014.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6022      0.119     38.558      0.000       4.367       4.837
# ...

# %%
#Model Building for RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
re= RandomForestRegressor(n_estimators=100,random_state=0)
re.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
#Getting predicted value
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 6.8155,  0.4766,  4.5605,  8.7235, 15.1007,  5.2155,  3.1885,
#         0.4402,  3.768 ,  4.974 ,  2.813 ,  0.777 ,  4.8195,  7.1714,
#         7.7314, 15.1106,  6.5495,  3.9595,  0.4415,  1.593 ,  3.2355,
#         4.9385,  5.3035,  9.6527,  0.1933,  0.7473,  0.298 ,  0.6893,
#         0.477 ,  4.0419,  2.5245,  5.926 ,  0.4831,  7.4485,  3.2919,
#         1.1691,  5.62  ,  5.374 ,  0.2318,  7.9795,  7.9075, 21.9475,
#         4.8895,  4.4555,  5.6775, 11.5376,  0.2348,  0.7843,  5.28  ,
#         6.588 ,  6.4086,  3.101 ,  5.2615, 23.58  ,  1.1639,  1.1396,
#         0.4488,  2.5385,  3.539 ,  2.561 ,  3.7164])

# %%
y_test
# Out:
# 223     8.25
# 150     0.50
# 226     5.25
# 296     9.50
# 52     18.00
#        ...
# 137     0.65
# 227     2.55
# 26      4.15
# 106     1.35
# 92      3.51
# Name: Selling_Price, Length: 61, dtype: float64

# %%
#Checking accuracy for Random forest Regressor
model.score(x_test,y_test)
# Out:
# 0.9630617421807631

# %% [markdown]
# Observation:
# - Random forest Regressor gives more accuracy as compared to the linear regression model.
# - So, for this dataset Random forest Regresor is more suitable .
